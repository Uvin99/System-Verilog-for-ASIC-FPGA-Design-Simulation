# %%
import numpy as np
import serial

R=8
C=8

#serial.Serial(NAME_OF_UART_PORT, BAUD_RATE, READ_TIME_OUT)
ser = serial.Serial('COM3', 115200, timeout=0.050)
for i in range(20):
  print(f"****************** TEST {i+1} ************************\n\n")

  k = np.random.randint(low=-2**7, high=2**7, size=(R,C), dtype=np.int8)
  x = np.random.randint(low=-2**7, high=2**7, size=(C), dtype=np.int8)
  y_exp = k.astype(np.int32) @ x.astype(np.int32)

  '''
  Send k & x
  '''
  kx = np.concatenate([x, k.flatten()])
  kx_bytes = kx.tobytes()

  print(f"\n\n {k=} \n\n{x=} \n\n{kx=} \n\nSent: {kx_bytes= } \n\n")
  #Sending inputs to fpga
  no_of_bytes_sent = ser.write(kx_bytes)

  '''
  Receive y
  '''
  #recieving outputs from fpga 'R' elements, each of size 4 bytes 
  y_bytes = ser.read(R*4)
  y = np.frombuffer(y_bytes, dtype=np.int32)
  #print(y_exp.tobytes())

  print(f"Received: \n\n{y=} \n\n {y_exp=} \n\n\n")

  assert (y == y_exp), f"Output doesn't match: y:{y} != y_exp:{y_exp}"
# Out:
# ****************** TEST 1 ************************
#
#
#
#
#  k=array([[  -7,    4,    7,  -78,  -59, -116, -103,  -42],
#        [ -70,   -6, -111,  123,   44,   40,   14,   80],
#        [ -62,   25,   16,   86,   90,  112,   58,   28],
#        [ -26,  -21,  -10,   97,  -71,   65,   69,  -12],
#        [   1,  -85,   51,   23,  -64,  112,  -47,   69],
#        [ 122, -128, -110,   81,  -55,   22,   60,  -90],
#        [  67,  -92,  -56,  125, -122,  -49,  106,  -35],
#        [ 110,  -69,  106,  -48,   77,  -37,  -89,   47]], dtype=int8)
#
# x=array([   6,  106,  -71, -113,  -59,  110,   86,  -45], dtype=int8)
#
# kx=array([   6,  106,  -71, -113,  -59,  110,   86,  -45,   -7,    4,    7,
#         -78,  -59, -116, -103,  -42,  -70,   -6, -111,  123,   44,   40,
#          14,   80,  -62,   25,   16,   86,   90,  112,   58,   28,  -26,
#         -21,  -10,   97,  -71,   65,   69,  -12,    1,  -85,   51,   23,
#         -64,  112,  -47,   69,  122, -128, -110,   81,  -55,   22,   60,
#         -90,   67,  -92,  -56,  125, -122,  -49,  106,  -35,  110,  -69,
#         106,  -48,   77,  -37,  -89,   47], dtype=int8)
#
# Sent: kx_bytes= b'\x06j\xb9\x8f\xc5nV\xd3\xf9\x04\x07\xb2\xc5\x8c\x99\xd6\xba\xfa\x91{,(\x0eP\xc2\x19\x10VZp:\x1c\xe6\xeb\xf6a\xb9AE\xf4\x01\xab3\x17\xc0p\xd1Ez\x80\x92Q\xc9\x16<\xa6C\xa4\xc8}\x86\xcfj\xddn\xbbj\xd0M\xdb\xa7/'
#
#
# Received:
#
# y=array([ -7548,  -7666,   2162,   5180,  -6275,    696,  -7000, -27138])
#
#  y_exp=array([ -7548,  -7666,   2162,   5180,  -6275,    696,  -7000, -27138])
#
#
#
# ****************** TEST 2 ************************
#
#
#
#
#  k=array([[ -28, -105,   -5,    0,  116,  111,   73,  -52],
#        [ -93,  -51,  -17,   47,  -79,  -24,    9, -119],
#        [-110,   45,   39,   85,  -96,  -96,   43, -100],
#        [  40,  -53,   76, -110,  -57,   20,   -6,   -3],
#        [ -68,   78,   71,   93,  -42,  -13,   59,  124],
#        [ -35,   54,   85,  -44,   19,  -22,  -13,   83],
#        [  92,   81,  -52,   73,   62,  -31,   36,   23],
#        [  64,   19,   15,    8, -126,   56,   69,    0]], dtype=int8)
#
# x=array([   0,   11,  -18,  -22, -100,  -47,    0,  -97], dtype=int8)
#
# kx=array([   0,   11,  -18,  -22, -100,  -47,    0,  -97,  -28, -105,   -5,
#           0,  116,  111,   73,  -52,  -93,  -51,  -17,   47,  -79,  -24,
#           9, -119, -110,   45,   39,   85,  -96,  -96,   43, -100,   40,
#         -53,   76, -110,  -57,   20,   -6,   -3,  -68,   78,   71,   93,
#         -42,  -13,   59,  124,  -35,   54,   85,  -44,   19,  -22,  -13,
#          83,   92,   81,  -52,   73,   62,  -31,   36,   23,   64,   19,
#          15,    8, -126,   56,   69,    0], dtype=int8)
#
# Sent: kx_bytes= b"\x00\x0b\xee\xea\x9c\xd1\x00\x9f\xe4\x97\xfb\x00toI\xcc\xa3\xcd\xef/\xb1\xe8\t\x89\x92-'U\xa0\xa0+\x9c(\xcbL\x92\xc7\x14\xfa\xfd\xbcNG]\xd6\xf3;|\xdd6U\xd4\x13\xea\xf3S\\Q\xccI>\xe1$\x17@\x13\x0f\x08\x828E\x00"
#
#
# Received:
#
# y=array([-12838,  19282,  21735,   5520,  -9683,  -8885,  -6753,   9731])
#
#  y_exp=array([-12838,  19282,  21735,   5520,  -9683,  -8885,  -6753,   9731])
#
#
#
# ****************** TEST 3 ************************
#
#
#
#
#  k=array([[  52,  -57, -116,  101,  114,   46,  -55,  -63],
#        [ 118,  -15, -126,  -37,  113,   70,  113,   46],
#        [ -99,  -61,  -36,  114, -104, -124,  -11,   92],
#        [  13,  -51, -114, -108,  109,  -49,  -80,  -23],
#        [  73,  -56,  -93,  -66,   16, -121,  -65,   28],
#        [ -40,  -32,  -61,  104, -114,  -54, -125, -115],
#        [  34,  -21,  101,   -8,  121,  -23,  122,   23],
#        [  97,  -14,  121,   38, -126,   62,   98,  121]], dtype=int8)
#
# x=array([  57,  -83,    5, -118,  -14,  -31,   69,  -28], dtype=int8)
#
# kx=array([  57,  -83,    5, -118,  -14,  -31,   69,  -28,   52,  -57, -116,
#         101,  114,   46,  -55,  -63,  118,  -15, -126,  -37,  113,   70,
#         113,   46,  -99,  -61,  -36,  114, -104, -124,  -11,   92,   13,
#         -51, -114, -108,  109,  -49,  -80,  -23,   73,  -56,  -93,  -66,
#          16, -121,  -65,   28,  -40,  -32,  -61,  104, -114,  -54, -125,
#        -115,   34,  -21,  101,   -8,  121,  -23,  122,   23,   97,  -14,
#         121,   38, -126,   62,   98,  121], dtype=int8)
#
# Sent: kx_bytes= b'9\xad\x05\x8a\xf2\xe1E\xe44\xc7\x8cer.\xc9\xc1v\xf1\x82\xdbqFq.\x9d\xc3\xdcr\x98\x84\xf5\\\r\xcd\x8e\x94m\xcf\xb0\xe9I\xc8\xa3\xbe\x10\x87\xbf\x1c\xd8\xe0\xc3h\x8e\xca\x83\x8d"\xebe\xf8y\xe9z\x17a\xf2y&\x82>by'
#
#
# Received:
#
# y=array([ -9856,  14464, -12247,  12265,  14390, -14336,  11923,   6028])
#
#  y_exp=array([ -9856,  14464, -12247,  12265,  14390, -14336,  11923,   6028])
#
#
#
# ****************** TEST 4 ************************
#
#
#
#
#  k=array([[ -31,  -25,   68,  -37,  120,   86,  103, -102],
#        [ -83,   34, -123,   39,  -61,  110,  -40,   55],
#        [ 100,   90,  -43,  105,   70,  -26,  -37,  -75],
#        [ 121,  -96,  -54, -120,  -50,   73,   13,  -20],
#        [   4,   70,   16, -103,   92,   24,  109,  -62],
#        [ -73,   47,  -96,  -57,  -58,   35, -125, -121],
#        [ -51,  104,   63,   73,  -15,   22,    5,   84],
#        [  37, -128,   68,    3,  -35,   83,  107,   66]], dtype=int8)
#
# x=array([-52,  31, -62,  93,  92,   0,   8, -24], dtype=int8)
#
# kx=array([ -52,   31,  -62,   93,   92,    0,    8,  -24,  -31,  -25,   68,
#         -37,  120,   86,  103, -102,  -83,   34, -123,   39,  -61,  110,
#         -40,   55,  100,   90,  -43,  105,   70,  -26,  -37,  -75,  121,
#         -96,  -54, -120,  -50,   73,   13,  -20,    4,   70,   16, -103,
#          92,   24,  109,  -62,  -73,   47,  -96,  -57,  -58,   35, -125,
#        -121,  -51,  104,   63,   73,  -15,   22,    5,   84,   37, -128,
#          68,    3,  -35,   83,  107,   66], dtype=int8)
#
# Sent: kx_bytes= b'\xcc\x1f\xc2]\\\x00\x08\xe8\xe1\xe7D\xdbxVg\x9a\xad"\x85\'\xc3n\xd87dZ\xd5iF\xe6\xdb\xb5y\xa0\xca\x88\xceI\r\xec\x04F\x10\x99\\\x18m\xc2\xb7/\xa0\xc7\xc6#\x83\x87\xcdh?I\xf1\x16\x05T%\x80D\x03\xddSkB'
#
#
# Received:
#
# y=array([  7492,   9371,  17965, -21096,   2215,   2472,   5403, -13777])
#
#  y_exp=array([  7492,   9371,  17965, -21096,   2215,   2472,   5403, -13777])
#
#
#
# ****************** TEST 5 ************************
#
#
#
#
#  k=array([[  86,   17,  -31,   55,  -82,  -70,  121,   76],
#        [ -64,  107,  -39,   61,  -77,   40,  -76,  -77],
#        [  29,  -44,   61,  -16,   19,   92,    1,   77],
#        [ -83, -100,  -63,  -31,   32,  -96,  -21, -106],
#        [ -91,   16,  -30,   86,  -26,  -96,  -82,  -41],
#        [  66,    7,  123,   35,   10, -122, -118,  -83],
#        [  -3, -105,   42,  117,  -71,   76,  -30,   37],
#        [ -81,    8,  -60,  -93,   81,  112,   18,   23]], dtype=int8)
#
# x=array([ -39,  -28,   80,   74,    8,    1,  -23, -121], dtype=int8)
#
# kx=array([ -39,  -28,   80,   74,    8,    1,  -23, -121,   86,   17,  -31,
#          55,  -82,  -70,  121,   76,  -64,  107,  -39,   61,  -77,   40,
#         -76,  -77,   29,  -44,   61,  -16,   19,   92,    1,   77,  -83,
#        -100,  -63,  -31,   32,  -96,  -21, -106,  -91,   16,  -30,   86,
#         -26,  -96,  -82,  -41,   66,    7,  123,   35,   10, -122, -118,
#         -83,   -3, -105,   42,  117,  -71,   76,  -30,   37,  -81,    8,
#         -60,  -93,   81,  112,   18,   23], dtype=int8)
#
# Sent: kx_bytes= b'\xd9\xe4PJ\x08\x01\xe9\x87V\x11\xe17\xae\xbayL\xc0k\xd9=\xb3(\xb4\xb3\x1d\xd4=\xf0\x13\\\x01M\xad\x9c\xc1\xe1 \xa0\xeb\x96\xa5\x10\xe2V\xe6\xa0\xae\xd7B\x07{#\n\x86\x8a\xad\xfd\x97*u\xb9L\xe2%\xaf\x08\xc4\xa3Qp\x12\x17'
#
#
# Received:
#
# y=array([-14945,  11383,  -5299,  12172,  13608,  22375,  10796, -11184])
#
#  y_exp=array([-14945,  11383,  -5299,  12172,  13608,  22375,  10796, -11184])
#
#
#
# ****************** TEST 6 ************************
#
#
#
#
#  k=array([[ 124,   -2, -113,  121, -110,  -19,   94,   59],
#        [ -96,    7,   44,   71, -114,  108,   56,  -26],
#        [-116, -124,   -9,  -84,  -94,  -14,  116,   46],
#        [  -5,  -10,  -47,  -52,  -65,   95,  -80,   32],
#        [-108,   27,  -51,   66,  -76,  -12,  -36, -112],
#        [ -62,   49, -108,  118,   23,   56,  -63,   75],
#        [ -14, -114,  -85,   96,   69,   58,   70, -116],
#        [-110,   47,  -61,  -75,   26,  -86,  -50,  -83]], dtype=int8)
#
# x=array([ 62,  49,  97,  -9, -41, -55,  46,  77], dtype=int8)
#
# kx=array([  62,   49,   97,   -9,  -41,  -55,   46,   77,  124,   -2, -113,
#         121, -110,  -19,   94,   59,  -96,    7,   44,   71, -114,  108,
#          56,  -26, -116, -124,   -9,  -84,  -94,  -14,  116,   46,   -5,
#         -10,  -47,  -52,  -65,   95,  -80,   32, -108,   27,  -51,   66,
#         -76,  -12,  -36, -112,  -62,   49, -108,  118,   23,   56,  -63,
#          75,  -14, -114,  -85,   96,   69,   58,   70, -116, -110,   47,
#         -61,  -75,   26,  -86,  -50,  -83], dtype=int8)
#
# Sent: kx_bytes= b'>1a\xf7\xd7\xc9.M|\xfe\x8fy\x92\xed^;\xa0\x07,G\x8el8\xe6\x8c\x84\xf7\xac\xa2\xf2t.\xfb\xf6\xd1\xcc\xbf_\xb0 \x94\x1b\xcdB\xb4\xf4\xdc\x90\xc21\x94v\x178\xc1K\xf2\x8e\xab`E:F\x8c\x92/\xc3\xb5\x1a\xaa\xce\xad'
#
#
# Received:
#
# y=array([  9962,  -2672,    117,  -8667, -17418, -14127, -27294, -14786])
#
#  y_exp=array([  9962,  -2672,    117,  -8667, -17418, -14127, -27294, -14786])
#
#
#
# ****************** TEST 7 ************************
#
#
#
#
#  k=array([[  61,   16,  -80, -113,   93,  -25,  -62,  -58],
#        [ -90,   16,    1, -104,   45, -106,   83,   53],
#        [ 103, -110,   21,  -58,  -27,   48,  -35,  -97],
#        [-112,  -83,  -12,  105, -125,  -14,   64,  -94],
#        [-112,   17,  115,  -16,  -91,  -70,   58,  -43],
#        [-122,   60,  -10,   76,   66, -109,   -5,   11],
#        [  51,   59,    4,  -76,  -13,  -69,   -6,  -16],
#        [ -12,  -32,   49,   93,  -11, -107,    2,   51]], dtype=int8)
#
# x=array([-61,  28, -43,   7, -27, 118,   0, -57], dtype=int8)
#
# kx=array([ -61,   28,  -43,    7,  -27,  118,    0,  -57,   61,   16,  -80,
#        -113,   93,  -25,  -62,  -58,  -90,   16,    1, -104,   45, -106,
#          83,   53,  103, -110,   21,  -58,  -27,   48,  -35,  -97, -112,
#         -83,  -12,  105, -125,  -14,   64,  -94, -112,   17,  115,  -16,
#         -91,  -70,   58,  -43, -122,   60,  -10,   76,   66, -109,   -5,
#          11,   51,   59,    4,  -76,  -13,  -69,   -6,  -16,  -12,  -32,
#          49,   93,  -11, -107,    2,   51], dtype=int8)
#
# Sent: kx_bytes= b'\xc3\x1c\xd5\x07\xe5v\x00\xc7=\x10\xb0\x8f]\xe7\xc2\xc6\xa6\x10\x01\x98-\x96S5g\x92\x15\xc6\xe50\xdd\x9f\x90\xad\xf4i\x83\xf2@\xa2\x90\x11s\xf0\xa5\xba:\xd5\x86<\xf6LB\x93\xfb\x0b3;\x04\xb4\xf3\xbb\xfa\xf0\xf4\xe01]\xf5\x95\x023'
#
#
# Received:
#
# y=array([ -2779, -11577,   1250,  12840,  -1101,  -5187,  -9042, -16856])
#
#  y_exp=array([ -2779, -11577,   1250,  12840,  -1101,  -5187,  -9042, -16856])
#
#
#
# ****************** TEST 8 ************************
#
#
#
#
#  k=array([[-119,   88,  110,  126,  -51, -100,   69,   41],
#        [ -27,  -72, -109,  -85,   62,  -64,   90,   29],
#        [ -93,  -22, -118,   67,  -87, -126,   46, -107],
#        [ 110,   37,   21,  -85,  123,   14,  -24,   43],
#        [  60,   49,   46,  -41,  -83,   30,   18,  112],
#        [ -11,    1, -125,  114,   99,   93,  122,   33],
#        [-102,  -37,   95,  -21,  115,  -99,  -94,  -63],
#        [  98, -124,  -25,   74,   41,   74,   80,  -51]], dtype=int8)
#
# x=array([127, 106,  77, 106,  83, -80, 126,  33], dtype=int8)
#
# kx=array([ 127,  106,   77,  106,   83,  -80,  126,   33, -119,   88,  110,
#         126,  -51, -100,   69,   41,  -27,  -72, -109,  -85,   62,  -64,
#          90,   29,  -93,  -22, -118,   67,  -87, -126,   46, -107,  110,
#          37,   21,  -85,  123,   14,  -24,   43,   60,   49,   46,  -41,
#         -83,   30,   18,  112,  -11,    1, -125,  114,   99,   93,  122,
#          33, -102,  -37,   95,  -21,  115,  -99,  -94,  -63,   98, -124,
#         -25,   74,   41,   74,   80,  -51], dtype=int8)
#
# Sent: kx_bytes= b'\x7fjMjS\xb0~!\x89Xn~\xcd\x9cE)\xe5\xb8\x93\xab>\xc0Z\x1d\xa3\xea\x8aC\xa9\x82.\x95n%\x15\xab{\x0e\xe8+<1.\xd7\xad\x1e\x12p\xf5\x01\x83rc]z!\x9a\xdb_\xebs\x9d\xa2\xc1b\x84\xe7J)JP\xcd'
#
#
# Received:
#
# y=array([ 29855,  -5901, -11003,  17983,   8685,  18406,  -8245,  11101])
#
#  y_exp=array([ 29855,  -5901, -11003,  17983,   8685,  18406,  -8245,  11101])
#
#
#
# ****************** TEST 9 ************************
#
#
#
#
#  k=array([[  79,   83,  -58,   19,   77, -113,    7,  -33],
#        [  71,  101,   55,    5,   51,   84,    2,   87],
#        [  36,   -2,  -36, -118,  -54,  111,  101, -109],
#        [-128,   29,  110,   -2,  -70,   74,   80,   18],
#        [  52,   74,   91,   19,  -94,   12,   27,   66],
#        [   9, -106,  -67,  -20,   34, -118,  -14,   20],
#        [ -44,  113,   15,  120,   94,  -58,   22,  -25],
#        [ -85,   94,  -48,  -35,   59,   82,  114,   91]], dtype=int8)
#
# x=array([ -37,  -37,  -60,   14, -100,   23,  107,  -73], dtype=int8)
#
# kx=array([ -37,  -37,  -60,   14, -100,   23,  107,  -73,   79,   83,  -58,
#          19,   77, -113,    7,  -33,   71,  101,   55,    5,   51,   84,
#           2,   87,   36,   -2,  -36, -118,  -54,  111,  101, -109, -128,
#          29,  110,   -2,  -70,   74,   80,   18,   52,   74,   91,   19,
#         -94,   12,   27,   66,    9, -106,  -67,  -20,   34, -118,  -14,
#          20,  -44,  113,   15,  120,   94,  -58,   22,  -25,  -85,   94,
#         -48,  -35,   59,   82,  114,   91], dtype=int8)
#
# Sent: kx_bytes= b'\xdb\xdb\xc4\x0e\x9c\x17k\xb7OS\xc6\x13M\x8f\x07\xdfGe7\x053T\x02W$\xfe\xdc\x8a\xcaoe\x93\x80\x1dn\xfe\xbaJP\x124J[\x13\xa2\x0c\x1bB\t\x96\xbd\xec"\x8a\xf2\x14\xd4q\x0fx^\xc6\x16\xe7\xab^\xd0\xdd;Rr['
#
#
# Received:
#
# y=array([ -9389, -18899,  25967,  12983,  -2109,  -1743,  -8328,   3598])
#
#  y_exp=array([ -9389, -18899,  25967,  12983,  -2109,  -1743,  -8328,   3598])
#
#
#
# ****************** TEST 10 ************************
#
#
#
#
#  k=array([[ -45,   15,    2,   60,   69,   61, -105,  -46],
#        [ -15,  -71, -115,  -62,   50,   26,  -67, -128],
#        [ -50,   25, -122,  -10,  122,   15,   82,   87],
#        [ 109,  -21,  -33,   62,  121,    6,  111,   91],
#        [-101,  -17, -113,   45,  -12,   79,  -44,  -68],
#        [ -44,  -47,  113,   92, -108,   23,   64,  122],
#        [ -94,  -58,    3, -119,   51,   55,  -79,    8],
#        [  72,  114,   63,   -3,  -47,  -43,   45,    7]], dtype=int8)
#
# x=array([ 19, 109,  99,  88, -15,  16,  22, -44], dtype=int8)
#
# kx=array([  19,  109,   99,   88,  -15,   16,   22,  -44,  -45,   15,    2,
#          60,   69,   61, -105,  -46,  -15,  -71, -115,  -62,   50,   26,
#         -67, -128,  -50,   25, -122,  -10,  122,   15,   82,   87,  109,
#         -21,  -33,   62,  121,    6,  111,   91, -101,  -17, -113,   45,
#         -12,   79,  -44,  -68,  -44,  -47,  113,   92, -108,   23,   64,
#         122,  -94,  -58,    3, -119,   51,   55,  -79,    8,   72,  114,
#          63,   -3,  -47,  -43,   45,    7], dtype=int8)
#
# Sent: kx_bytes= b'\x13mcX\xf1\x10\x16\xd4\xd3\x0f\x02<E=\x97\xd2\xf1\xb9\x8d\xc22\x1a\xbd\x80\xce\x19\x86\xf6z\x0fRWm\xeb\xdf>y\x06o[\x9b\xef\x8f-\xf4O\xd4\xbc\xd4\xd1q\\\x94\x17@z\xa2\xc6\x03\x8937\xb1\x08Hr?\xfd\xd1\xd5-\x07'
#
#
# Received:
#
# y=array([  5913, -21041, -14797,  -1310,  -7531,  11352, -20258,  20466])
#
#  y_exp=array([  5913, -21041, -14797,  -1310,  -7531,  11352, -20258,  20466])
#
#
#
# ****************** TEST 11 ************************
#
#
#
#
#  k=array([[ -89,  105,   21,   24, -123,   87,   -3,   95],
#        [ -13,  123,   74, -108, -117,   80,   -6,  -51],
#        [  89,  -13, -110,  -43, -127,   14,  -10,  -65],
#        [ -49,   73,  -11,   21,   52,  -50,   32,   99],
#        [  93,  106, -113,   72,   50,  -11,   94,  121],
#        [-123,  -30,  -81,  125,  -53,  124,   91,   80],
#        [ -18,  -15,    3,   20,  -21,   32,  -60,  -57],
#        [  82,  111,   74,   44,    3,  -76,  -36,   93]], dtype=int8)
#
# x=array([-73, -16, -45,  84,  50, -90, -28,   0], dtype=int8)
#
# kx=array([ -73,  -16,  -45,   84,   50,  -90,  -28,    0,  -89,  105,   21,
#          24, -123,   87,   -3,   95,  -13,  123,   74, -108, -117,   80,
#          -6,  -51,   89,  -13, -110,  -43, -127,   14,  -10,  -65,  -49,
#          73,  -11,   21,   52,  -50,   32,   99,   93,  106, -113,   72,
#          50,  -11,   94,  121, -123,  -30,  -81,  125,  -53,  124,   91,
#          80,  -18,  -15,    3,   20,  -21,   32,  -60,  -57,   82,  111,
#          74,   44,    3,  -76,  -36,   93], dtype=int8)
#
# Sent: kx_bytes= b'\xb7\xf0\xd3T2\xa6\xe4\x00\xa7i\x15\x18\x85W\xfd_\xf3{J\x94\x8bP\xfa\xcdY\xf3\x92\xd5\x81\x0e\xf6\xbf\xcfI\xf5\x154\xce c]j\x8fH2\xf5^y\x85\xe2\xaf}\xcb|[P\xee\xf1\x03\x14\xeb \xc4\xc7RoJ,\x03\xb4\xdc]'
#
#
# Received:
#
# y=array([ -8008, -26303, -12281,  10872,   3506,   7246,    849,    602])
#
#  y_exp=array([ -8008, -26303, -12281,  10872,   3506,   7246,    849,    602])
#
#
#
# ****************** TEST 12 ************************
#
#
#
#
#  k=array([[  57,   35,   26,   -4,  -61,  112,  -74,   36],
#        [ -82,  -81,   59, -113,   84,  -91,   96,   21],
#        [ 126,  -24,  -65,  -70, -109,   41,   14,  -47],
#        [-107,   99,   57,   31,   13,  126,   81,  -99],
#        [-102,  -32,  -35,   -8,   50,  -99,  -85,   48],
#        [  85,   57,  107,  -54,  -63, -115,   14,   26],
#        [ -82,  119, -102,  -94,   39, -122,   90,   90],
#        [-114,   43,  -66,   64,   61,   60,  -93,    0]], dtype=int8)
#
# x=array([ -75,   86,  103,   32,    3,  -35, -105,  102], dtype=int8)
#
# kx=array([ -75,   86,  103,   32,    3,  -35, -105,  102,   57,   35,   26,
#          -4,  -61,  112,  -74,   36,  -82,  -81,   59, -113,   84,  -91,
#          96,   21,  126,  -24,  -65,  -70, -109,   41,   14,  -47, -107,
#          99,   57,   31,   13,  126,   81,  -99, -102,  -32,  -35,   -8,
#          50,  -99,  -85,   48,   85,   57,  107,  -54,  -63, -115,   14,
#          26,  -82,  119, -102,  -94,   39, -122,   90,   90, -114,   43,
#         -66,   64,   61,   60,  -93,    0], dtype=int8)
#
# Sent: kx_bytes= b"\xb5Vg \x03\xdd\x97f9#\x1a\xfc\xc3p\xb6$\xae\xaf;\x8fT\xa5`\x15~\xe8\xbf\xba\x93)\x0e\xd1\x95c9\x1f\r~Q\x9d\x9a\xe0\xdd\xf82\x9d\xab0U9k\xca\xc1\x8d\x0e\x1a\xaew\x9a\xa2'\x86ZZ\x8e+\xbe@=<\xa3\x00"
#
#
# Received:
#
# y=array([  8624,  -2856, -28475,    428,  18473,  12838,   6987,  15346])
#
#  y_exp=array([  8624,  -2856, -28475,    428,  18473,  12838,   6987,  15346])
#
#
#
# ****************** TEST 13 ************************
#
#
#
#
#  k=array([[  99,  106,  105, -112,   70,   85, -106,  -11],
#        [  36,  -10, -120,   41,  -13,    6,  106,  125],
#        [ 114,   12,   34,  102,   72,  113,  -43,  -40],
#        [ 108,  120,  119,   79,   17,   98,   82,   52],
#        [  54,  105,   47,  -57,   44, -118,  -61,   41],
#        [  48,  -29,  -22,    9,   76,   62,    6,  -57],
#        [ -59,  -51,   11,  -63,  115,  -35,    9,  110],
#        [  98, -115,   -5,  -54,   58, -108,  -11,   92]], dtype=int8)
#
# x=array([ 71,  13,  61,  85, 102,  18, -26, 104], dtype=int8)
#
# kx=array([  71,   13,   61,   85,  102,   18,  -26,  104,   99,  106,  105,
#        -112,   70,   85, -106,  -11,   36,  -10, -120,   41,  -13,    6,
#         106,  125,  114,   12,   34,  102,   72,  113,  -43,  -40,  108,
#         120,  119,   79,   17,   98,   82,   52,   54,  105,   47,  -57,
#          44, -118,  -61,   41,   48,  -29,  -22,    9,   76,   62,    6,
#         -57,  -59,  -51,   11,  -63,  115,  -35,    9,  110,   98, -115,
#          -5,  -54,   58, -108,  -11,   92], dtype=int8)
#
# Sent: kx_bytes= b'G\r=Uf\x12\xe6hcji\x90FU\x96\xf5$\xf6\x88)\xf3\x06j}r\x0c"fHq\xd5\xd8lxwO\x11bR46i/\xc7,\x8a\xc3)0\xe3\xea\tL>\x06\xc7\xc5\xcd\x0b\xc1s\xdd\tnb\x8d\xfb\xca:\x94\xf5\\'
#
#
# Received:
#
# y=array([15574,  7617, 25330, 29976, 11435,  5238, 12770, 14394])
#
#  y_exp=array([15574,  7617, 25330, 29976, 11435,  5238, 12770, 14394])
#
#
#
# ****************** TEST 14 ************************
#
#
#
#
#  k=array([[ -58,  119,  -66,  -69,  116,  122, -119,   25],
#        [ 114,  -26,  -39,   -9,  -46,  -88,  121,  -63],
#        [  10,   98,   79, -116, -100,  -28,  -29,   91],
#        [  39,   42, -108,  -74,   14,  -97,   84,   75],
#        [ 101,  107,  -66,  -80,  102,  -90,   62,  125],
#        [-103,   22,   42,  -79,   16,  -85,   47,   79],
#        [ 110,   50,   73,   63,  105,   96,   49,  -61],
#        [-115,    5,  -86,  -92,   51,   96,   70,   44]], dtype=int8)
#
# x=array([ 111,   41,   45,  100,  -97,   52, -112,  114], dtype=int8)
#
# kx=array([ 111,   41,   45,  100,  -97,   52, -112,  114,  -58,  119,  -66,
#         -69,  116,  122, -119,   25,  114,  -26,  -39,   -9,  -46,  -88,
#         121,  -63,   10,   98,   79, -116, -100,  -28,  -29,   91,   39,
#          42, -108,  -74,   14,  -97,   84,   75,  101,  107,  -66,  -80,
#         102,  -90,   62,  125, -103,   22,   42,  -79,   16,  -85,   47,
#          79,  110,   50,   73,   63,  105,   96,   49,  -61, -115,    5,
#         -86,  -92,   51,   96,   70,   44], dtype=int8)
#
# Sent: kx_bytes= b"o)-d\x9f4\x90r\xc6w\xbe\xbbtz\x89\x19r\xe6\xd9\xf7\xd2\xa8y\xc1\nbO\x8c\x9c\xe4\xe3['*\x94\xb6\x0e\x9fTKek\xbe\xb0f\xa6>}\x99\x16*\xb1\x10\xab/On2I?i`1\xc3\x8d\x05\xaa\xa43`F,"
#
#
# Received:
#
# y=array([  -159, -11915,  18949, -13469,  -2640, -18771,   6210, -28409])
#
#  y_exp=array([  -159, -11915,  18949, -13469,  -2640, -18771,   6210, -28409])
#
#
#
# ****************** TEST 15 ************************
#
#
#
#
#  k=array([[  -9,    0, -128, -126, -120,   63,  -70,  -53],
#        [  -6,   84,  -61,   26,   87,   81,   -5,  116],
#        [ -90,   75,    2,  112,   30,   47,  -87,   44],
#        [   9,   11,  -16,   40,   80, -110, -123,  -93],
#        [  81,    0,   94,   79,  118,   11, -113, -113],
#        [  97,  -34,  100, -100,   78,  -99,  -53,  -44],
#        [ 106,  117,    3,   75,   64,  -26, -122, -102],
#        [  92,   47,   43,  -82,    6,  -13,  -85,   36]], dtype=int8)
#
# x=array([  94,  -36,  101, -128,   71,  -60,  -31,  100], dtype=int8)
#
# kx=array([  94,  -36,  101, -128,   71,  -60,  -31,  100,   -9,    0, -128,
#        -126, -120,   63,  -70,  -53,   -6,   84,  -61,   26,   87,   81,
#          -5,  116,  -90,   75,    2,  112,   30,   47,  -87,   44,    9,
#          11,  -16,   40,   80, -110, -123,  -93,   81,    0,   94,   79,
#         118,   11, -113, -113,   97,  -34,  100, -100,   78,  -99,  -53,
#         -44,  106,  117,    3,   75,   64,  -26, -122, -102,   92,   47,
#          43,  -82,    6,  -13,  -85,   36], dtype=int8)
#
# Sent: kx_bytes= b'^\xdce\x80G\xc4\xe1d\xf7\x00\x80\x82\x88?\xba\xcb\xfaT\xc3\x1aWQ\xfbt\xa6K\x02p\x1e/\xa9,\t\x0b\xf0(P\x92\x85\xa3Q\x00^Ov\x0b\x8f\x8fa\xded\x9cN\x9d\xcb\xd4ju\x03K@\xe6\x86\x9a\\/+\xae\x06\xf3\xab$'
#
#
# Received:
#
# y=array([-13076,     -5, -18887,    507,   6917,  41963,  -3859,  29236])
#
#  y_exp=array([-13076,     -5, -18887,    507,   6917,  41963,  -3859,  29236])
#
#
#
# ****************** TEST 16 ************************
#
#
#
#
#  k=array([[ -75,   81, -110,  -35,  -85, -102,  -73,   40],
#        [  37,  -89,  -17, -121,  -28,   90,   57,  -35],
#        [ 109,   64,  -57,  -80,   54,  111, -128,   87],
#        [  67,   63,   71,  -72,  126,  -40,  -73,   39],
#        [-109,   80, -119,   61,  -34,  117,   83,  -56],
#        [  -4,  -94,  -85,  -97, -101,   83,   39,   22],
#        [  69,  -51,  -92,  -72,   84,  -16,    2,   19],
#        [  11,   92,   93,  -12,  -69,  -20,   16,  -78]], dtype=int8)
#
# x=array([ 23,  49, -73, -92,  30, -34, -22,  77], dtype=int8)
#
# kx=array([  23,   49,  -73,  -92,   30,  -34,  -22,   77,  -75,   81, -110,
#         -35,  -85, -102,  -73,   40,   37,  -89,  -17, -121,  -28,   90,
#          57,  -35,  109,   64,  -57,  -80,   54,  111, -128,   87,   67,
#          63,   71,  -72,  126,  -40,  -73,   39, -109,   80, -119,   61,
#         -34,  117,   83,  -56,   -4,  -94,  -85,  -97, -101,   83,   39,
#          22,   69,  -51,  -92,  -72,   84,  -16,    2,   19,   11,   92,
#          93,  -12,  -69,  -20,   16,  -78], dtype=int8)
#
# Sent: kx_bytes= b"\x171\xb7\xa4\x1e\xde\xeaM\xb5Q\x92\xdd\xab\x9a\xb7(%\xa7\xef\x87\xe4Z9\xddm@\xc7\xb06o\x80WC?G\xb8~\xd8\xb7'\x93P\x89=\xdeuS\xc8\xfc\xa2\xab\x9f\x9bS'\x16E\xcd\xa4\xb8T\xf0\x02\x13\x0b\\]\xf4\xbb\xec\x10\xb2"
#
#
# Received:
#
# y=array([19098,  1014, 24525, 15818, -6648,  5415, 16911, -8672])
#
#  y_exp=array([19098,  1014, 24525, 15818, -6648,  5415, 16911, -8672])
#
#
#
# ****************** TEST 17 ************************
#
#
#
#
#  k=array([[ 118,    5, -108, -117, -102,   69, -107,  -92],
#        [  34,  -36,  -85, -108,   68,    4, -114, -100],
#        [  -2,  -29,  104,   -5, -105,   22,   76,   39],
#        [ -10,  -96,    3,  -33,   68,  -86,   -6,   21],
#        [  47,  -26,   55,  -65,  -84, -121,   34,  -83],
#        [  55,  -60,  105,   61,  -98,  -87,  -83,  108],
#        [ -49,  -84,   70,  107,  -13,  -63, -104,   11],
#        [ -13,   98,   91,   -9,   82,  -13,  -84,  -73]], dtype=int8)
#
# x=array([-39, 124, 115, -23,  80, -95, 113,  16], dtype=int8)
#
# kx=array([ -39,  124,  115,  -23,   80,  -95,  113,   16,  118,    5, -108,
#        -117, -102,   69, -107,  -92,   34,  -36,  -85, -108,   68,    4,
#        -114, -100,   -2,  -29,  104,   -5, -105,   22,   76,   39,  -10,
#         -96,    3,  -33,   68,  -86,   -6,   21,   47,  -26,   55,  -65,
#         -84, -121,   34,  -83,   55,  -60,  105,   61,  -98,  -87,  -83,
#         108,  -49,  -84,   70,  107,  -13,  -63, -104,   11,  -13,   98,
#          91,   -9,   82,  -13,  -84,  -73], dtype=int8)
#
# Sent: kx_bytes= b'\xd9|s\xe9P\xa1q\x10v\x05\x94\x8b\x9aE\x95\xa4"\xdc\xab\x94D\x04\x8e\x9c\xfe\xe3h\xfb\x97\x16L\'\xf6\xa0\x03\xdfD\xaa\xfa\x15/\xe67\xbf\xac\x87"\xad7\xc4i=\x9e\xa9\xadl\xcf\xacFk\xf3\xc1\x98\x0b\xf3b[\xf7R\xf3\xac\xb7'
#
#
# Received:
#
# y=array([-41989, -22503,   7279,   2858,  10052,  -6139,  -9547,  20466])
#
#  y_exp=array([-41989, -22503,   7279,   2858,  10052,  -6139,  -9547,  20466])
#
#
#
# ****************** TEST 18 ************************
#
#
#
#
#  k=array([[ -34,   -9, -103,  -63,  -88,   60,   18,  -26],
#        [   6, -118,  -12,   95, -127,    9,   43,   71],
#        [ -49,   94,  -25,  -26,   99,   76,    1,  -80],
#        [ 127, -113,   47,  121,   25,   17, -124,   51],
#        [ 107,   92,   24,   58,    0,  -76, -124,   74],
#        [ -20,   35,   45,  -79,  -26,   51,  -24,   66],
#        [  56,  -19, -122,   56,  -38, -119,  114,  108],
#        [  92,  -87,   18,  125,  -75,  118,  -96,   16]], dtype=int8)
#
# x=array([ -78,  -20,   65,  -51,  118,   91, -123,   66], dtype=int8)
#
# kx=array([ -78,  -20,   65,  -51,  118,   91, -123,   66,  -34,   -9, -103,
#         -63,  -88,   60,   18,  -26,    6, -118,  -12,   95, -127,    9,
#          43,   71,  -49,   94,  -25,  -26,   99,   76,    1,  -80,  127,
#        -113,   47,  121,   25,   17, -124,   51,  107,   92,   24,   58,
#           0,  -76, -124,   74,  -20,   35,   45,  -79,  -26,   51,  -24,
#          66,   56,  -19, -122,   56,  -38, -119,  114,  108,   92,  -87,
#          18,  125,  -75,  118,  -96,   16], dtype=int8)
#
# Sent: kx_bytes= b'\xb2\xecA\xcdv[\x85B\xde\xf7\x99\xc1\xa8<\x12\xe6\x06\x8a\xf4_\x81\t+G\xcf^\xe7\xe6cL\x01\xb0\x7f\x8f/y\x19\x11\x843k\\\x18:\x00\xb4\x84J\xec#-\xb1\xe63\xe8B8\xed\x868\xda\x89rl\\\xa9\x12}\xb5v\xa0\x10'
#
#
# Received:
#
# y=array([ -9504, -18503,  14838,  12353,   1636,  16695, -36981,   4111])
#
#  y_exp=array([ -9504, -18503,  14838,  12353,   1636,  16695, -36981,   4111])
#
#
#
# ****************** TEST 19 ************************
#
#
#
#
#  k=array([[ 110,   22,   42,  115,   24,   63, -112, -117],
#        [ -57,  125,  -66,   84, -126,   61,  -19,  -91],
#        [ -42,  125,  -75,   -8, -102,   46,  -34,  -80],
#        [-119,   78,   33,  -92,   -9, -111,   30,  119],
#        [  26,   41,   79,   52,  -66,  -85,   24, -118],
#        [ -90,   67, -104, -126,   -9,  115,   78,   32],
#        [ -80,  -27,  -21,   61,   31,   10,  -13, -115],
#        [  -8,   38,  111,  114, -124,   88,   26,   88]], dtype=int8)
#
# x=array([100,   2, -96,  10, 114, -94, -87,  64], dtype=int8)
#
# kx=array([ 100,    2,  -96,   10,  114,  -94,  -87,   64,  110,   22,   42,
#         115,   24,   63, -112, -117,  -57,  125,  -66,   84, -126,   61,
#         -19,  -91,  -42,  125,  -75,   -8, -102,   46,  -34,  -80, -119,
#          78,   33,  -92,   -9, -111,   30,  119,   26,   41,   79,   52,
#         -66,  -85,   24, -118,  -90,   67, -104, -126,   -9,  115,   78,
#          32,  -80,  -27,  -21,   61,   31,   10,  -13, -115,   -8,   38,
#         111,  114, -124,   88,   26,   88], dtype=int8)
#
# Sent: kx_bytes= b'd\x02\xa0\nr\xa2\xa9@n\x16*s\x18?\x90\x8b\xc7}\xbeT\x82=\xed\xa5\xd6}\xb5\xf8\x9a.\xde\xb0\x89N!\xa4\xf7\x91\x1ew\x1a)O4\xbe\xab\x18\x8a\xa6C\x98\x82\xf7sN \xb0\xe5\xeb=\x1f\n\xf3\x8d\xf8&or\x84X\x1aX'
#
#
# Received:
#
# y=array([  7232, -22543, -14944,  -1418, -13556, -16716,  -9063, -29278])
#
#  y_exp=array([  7232, -22543, -14944,  -1418, -13556, -16716,  -9063, -29278])
#
#
#
# ****************** TEST 20 ************************
#
#
#
#
#  k=array([[ 124,   45,  -64,  118,   -1,  -96,  -73,   92],
#        [ -86,  -13, -123, -111, -113,  -56,  -18, -123],
#        [ -12,  114, -124,   -8,   17,  123,  120,  -18],
#        [  10,   43,   71,   84, -109,  126,   80,  -32],
#        [ -25,   18,   -3,  -33,   49,   57,   -6,  -21],
#        [ -73,  -14,  -14,  -34,  -82, -113,  -21,  -17],
#        [  19,  -14, -108,  106,    1,  121, -100,  -93],
#        [  41,   62,  -36,   85,   80,  -95,   53,   50]], dtype=int8)
#
# x=array([ 81,  41,  76,  67, 101, -22, -78,  75], dtype=int8)
#
# kx=array([  81,   41,   76,   67,  101,  -22,  -78,   75,  124,   45,  -64,
#         118,   -1,  -96,  -73,   92,  -86,  -13, -123, -111, -113,  -56,
#         -18, -123,  -12,  114, -124,   -8,   17,  123,  120,  -18,   10,
#          43,   71,   84, -109,  126,   80,  -32,  -25,   18,   -3,  -33,
#          49,   57,   -6,  -21,  -73,  -14,  -14,  -34,  -82, -113,  -21,
#         -17,   19,  -14, -108,  106,    1,  121, -100,  -93,   41,   62,
#         -36,   85,   80,  -95,   53,   50], dtype=int8)
#
# Sent: kx_bytes= b'Q)LCe\xea\xb2K|-\xc0v\xff\xa0\xb7\\\xaa\xf3\x85\x91\x8f\xc8\xee\x85\xf4r\x84\xf8\x11{x\xee\n+GT\x93~P\xe0\xe7\x12\xfd\xdf19\xfa\xeb\xb7\xf2\xf2\xde\xae\x8f\xeb\xef\x13\xf2\x94j\x01y\x9c\xa3)>\xdcUP\xa152'
#
#
# Received:
#
# y=array([ 29536, -42286, -17957,  -8824,  -1138, -15262,  -1877,  18608])
#
#  y_exp=array([ 29536, -42286, -17957,  -8824,  -1138, -15262,  -1877,  18608])
